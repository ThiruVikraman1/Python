# %%
from SubFields import SubFieldsInAI

# %%
SubFieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
# Create a class function that checks whether the given number is Odd or Even
from Odd_Even import OddEven

# %%
OddEven.OddEven()
# Out:
# 34 is even number

# %%
# Create a function that tells elegibility of marriage for male and female according to their age limit like 21 for male and 18 for female
from Marriage_Eligiblity import EligiblityForMarriage

# %%
EligiblityForMarriage.Eligible()
# Out:
# Gender: female
# Age: 23
# ELIGIBLE

# %%
# calculate the percentage of your 10th mark
from percentage import FindPercent

# %%
FindPercent.percentage()
# Out:
# 86.8

# %%
#print area and perimeter of triangle using class and functions
from Area_Perimeter import AreaPerimeter

# %%
AreaPerimeter.Triangle()
# Out:
# Area formula: (Height*Base)/2
# Area of triangle: 10.0
# Perimeter formula: Side1+Side2+Base
# Perimeter of Triangle: 11
